# %% [markdown]
# Name: **Luong Nguyen**
# Student ID: **1504210**

# %% [markdown]
# ## Introduction to Deep Learning
#
# ### Session01: Linear model for grading
# ____

# %% [markdown]
# **Import the packages needed for this assignment**

# %%
# import packages
import numpy as np
import keras

# %% [markdown]
# **Load data**

# %%
with np.load("grading.npz") as data:
    x = data[ 'x' ]
    y = data[ 'y' ]

# %% [markdown]
# **Explore data**

# %%
print("x shape: " + str(x.shape))
print("y shape: " + str(y.shape))
print("An example of points from the course: " + str(x[5]))
print("And the corresponding grade: " + str(y[5]))
print()

mean_x = np.mean(x, axis=0)
std_x = np.std(x, axis=0)
max_x = np.max(x, axis=0)
min_x = np.min(x, axis=0)
print("Mean of x: " + str(mean_x))
print("Min of x: " + str(min_x))
print("Max of x: " + str(max_x))
print()

mean_y = np.mean(y)
max_y = np.max(y)
min_y = np.min(y)
print("Mean of y: " + str(mean_y))
print("Min of y: " + str(min_y))
print("Max of y: " + str(max_y))
# Out:
# x shape: (4000, 3)
# y shape: (4000,)
# An example of points from the course: [66. 27. 48.]
# And the corresponding grade: 2.0
#
# Mean of x: [74.01725 55.40175 61.82125]
# Min of x: [ 7.  0. 25.]
# Max of x: [100. 100.  98.]
#
# Mean of y: 3.03275
# Min of y: 0.0
# Max of y: 5.0

# %% [markdown]
# **Standardize data**

# %%
x -= mean_x
x /= std_x # your example x_train /= (2 * std)

print("A standardized row data: " + str(x[5]))
# Out:
# A standardized row data: [-0.44488305 -1.448874   -0.63900849]

# %% [markdown]
# **Split data into train and test sets**

# %%
# https://stackoverflow.com/questions/3674409/how-to-split-partition-a-dataset-into-training-and-test-datasets-for-e-g-cros
indices = np.random.permutation(x.shape[0])
m_train = 3000
m_test = 1000

train_idx, test_idx = indices[:m_train], indices[m_train:]
train_x, test_x = x[train_idx,:], x[test_idx,:]
train_y, test_y = y[train_idx], y[test_idx]

print ("train_x shape: " + str(train_x.shape))
print ("train_y shape: " + str(train_y.shape))
print ("test_x shape: " + str(test_x.shape))
print ("test_y shape: " + str(test_y.shape))
# Out:
# train_x shape: (3000, 3)
# train_y shape: (3000,)
# test_x shape: (1000, 3)
# test_y shape: (1000,)

# %% [markdown]
# We randomly assigned 4000 samples into a train set with 3000 samples and a test set with 1000 samples.

# %% [markdown]
# **Build model**

# %%
model = keras.models.Sequential()
model.add(keras.layers.Dense(1, input_shape=(3,)))

model.compile(loss='mse', optimizer='sgd')
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 1)                 4
# =================================================================
# Total params: 4
# Trainable params: 4
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Train model**

# %%
def predict(epochs, batch_size):
    """
    Helper function - takes in epochs and batch_size arguments, train the model and print out prediction accuracy and model weight
    """
    print("#############################################################################################")
    print("Training model with epochs = {0}, batch_size = {1}".format(epochs, batch_size))
    hist = model.fit(train_x, train_y, epochs=epochs, batch_size=batch_size)

    prediction_test = model.predict(test_x).reshape(m_test,)
    prediction_train = model.predict(train_x).reshape(m_train,)

    print("\tTrain accuracy: {} %".format(np.sum(np.round(prediction_train) == train_y) / m_train * 100))
    print("\tTest accuracy: {} %".format(np.sum(np.round(prediction_test) == test_y) / m_test * 100))

    print("\tWeight: ")
    print(model.get_weights())

# %%
# Does training with more epochs help?
epochs_list = [5, 10, 25, 30]
batch_size = 20

for epochs in epochs_list:
    predict(epochs, batch_size)
# Out:
# #############################################################################################
# Training model with epochs = 5, batch_size = 20
# Epoch 1/5
# 3000/3000 [==============================] - 0s 54us/step - loss: 0.1949
# Epoch 2/5
# 3000/3000 [==============================] - 0s 51us/step - loss: 0.1949
# Epoch 3/5
# 3000/3000 [==============================] - 0s 50us/step - loss: 0.1948
# Epoch 4/5
# 3000/3000 [==============================] - 0s 49us/step - loss: 0.1948
# Epoch 5/5
# 3000/3000 [==============================] - 0s 50us/step - loss: 0.1947
# 	Train accuracy: 78.53333333333333 %
# 	Test accuracy: 77.10000000000001 %
# 	Weight:
# [array([[1.314534  ],
#        [0.31233355],
#        [0.35144585]], dtype=float32), array([3.015653], dtype=float32)]
# #############################################################################################
# Training model with epochs = 10, batch_size = 20
# Epoch 1/10
# 3000/3000 [==============================] - 0s 50us/step - loss: 0.1948
# Epoch 2/10
# 3000/3000 [==============================] - 0s 53us/step - loss: 0.1943
# Epoch 3/10
# 3000/3000 [==============================] - 0s 52us/step - loss: 0.1949
# Epoch 4/10
# 3000/3000 [==============================] - 0s 54us/step - loss: 0.1949
# Epoch 5/10
# 3000/3000 [==============================] - 0s 58us/step - loss: 0.1945
# Epoch 6/10
# 3000/3000 [==============================] - 0s 58us/step - loss: 0.1949
# Epoch 7/10
# 3000/3000 [==============================] - 0s 60us/step - loss: 0.1949
# Epoch 8/10
# 3000/3000 [==============================] - 0s 55us/step - loss: 0.1948
# Epoch 9/10
# 3000/3000 [==============================] - 0s 58us/step - loss: 0.1949
# Epoch 10/10
# 3000/3000 [==============================] - 0s 56us/step - loss: 0.1945
# 	Train accuracy: 78.83333333333333 %
# 	Test accuracy: 76.8 %
# 	Weight:
# [array([[1.318964 ],
#        [0.3190328],
#        [0.3460534]], dtype=float32), array([3.026141], dtype=float32)]
# #############################################################################################
# Training model with epochs = 25, batch_size = 20
# Epoch 1/25
# 3000/3000 [==============================] - 0s 56us/step - loss: 0.1947
# Epoch 2/25
# 3000/3000 [==============================] - 0s 56us/step - loss: 0.1949
# Epoch 3/25
# 3000/3000 [==============================] - 0s 58us/step - loss: 0.1946
# Epoch 4/25
# 3000/3000 [==============================] - 0s 57us/step - loss: 0.1949
# Epoch 5/25
# 3000/3000 [==============================] - 0s 85us/step - loss: 0.1948
# Epoch 6/25
# 3000/3000 [==============================] - 0s 58us/step - loss: 0.1948
# Epoch 7/25
# 3000/3000 [==============================] - 0s 52us/step - loss: 0.1944
# Epoch 8/25
# 3000/3000 [==============================] - 0s 67us/step - loss: 0.1949
# Epoch 9/25
# 3000/3000 [==============================] - 0s 60us/step - loss: 0.1948
# Epoch 10/25
# 3000/3000 [==============================] - 0s 71us/step - loss: 0.1949
# Epoch 11/25
# 3000/3000 [==============================] - 0s 97us/step - loss: 0.1946
# Epoch 12/25
# 3000/3000 [==============================] - 0s 95us/step - loss: 0.1946
# Epoch 13/25
# 3000/3000 [==============================] - 0s 55us/step - loss: 0.1948
# Epoch 14/25
# 3000/3000 [==============================] - 0s 57us/step - loss: 0.1946
# Epoch 15/25
# 3000/3000 [==============================] - 0s 60us/step - loss: 0.1950
# Epoch 16/25
# 3000/3000 [==============================] - 0s 59us/step - loss: 0.1946
# Epoch 17/25
# 3000/3000 [==============================] - 0s 56us/step - loss: 0.1949
# Epoch 18/25
# 3000/3000 [==============================] - 0s 62us/step - loss: 0.1949
# Epoch 19/25
# 3000/3000 [==============================] - 0s 87us/step - loss: 0.1949
# Epoch 20/25
# 3000/3000 [==============================] - 0s 63us/step - loss: 0.1946
# Epoch 21/25
# 3000/3000 [==============================] - 0s 61us/step - loss: 0.1949
# Epoch 22/25
# 3000/3000 [==============================] - 0s 55us/step - loss: 0.1944
# Epoch 23/25
# 3000/3000 [==============================] - 0s 56us/step - loss: 0.1949
# Epoch 24/25
# 3000/3000 [==============================] - 0s 71us/step - loss: 0.1948
# Epoch 25/25
# 3000/3000 [==============================] - 0s 67us/step - loss: 0.1948
# 	Train accuracy: 79.66666666666666 %
# 	Test accuracy: 78.7 %
# 	Weight:
# [array([[1.3081504 ],
#        [0.33257544],
#        [0.3601869 ]], dtype=float32), array([3.0315347], dtype=float32)]
# #############################################################################################
# Training model with epochs = 30, batch_size = 20
# Epoch 1/30
# 3000/3000 [==============================] - 0s 60us/step - loss: 0.1946
# Epoch 2/30
# 3000/3000 [==============================] - 0s 59us/step - loss: 0.1949
# Epoch 3/30
# 3000/3000 [==============================] - 0s 61us/step - loss: 0.1949
# Epoch 4/30
# 3000/3000 [==============================] - 0s 55us/step - loss: 0.1948
# Epoch 5/30
# 3000/3000 [==============================] - 0s 58us/step - loss: 0.1948
# Epoch 6/30
# 3000/3000 [==============================] - 0s 59us/step - loss: 0.1948
# Epoch 7/30
# 3000/3000 [==============================] - 0s 63us/step - loss: 0.1948
# Epoch 8/30
# 3000/3000 [==============================] - 0s 58us/step - loss: 0.1949
# Epoch 9/30
# 3000/3000 [==============================] - 0s 57us/step - loss: 0.1950
# Epoch 10/30
# 3000/3000 [==============================] - 0s 57us/step - loss: 0.1946
# Epoch 11/30
# 3000/3000 [==============================] - 0s 63us/step - loss: 0.1948
# Epoch 12/30
# 3000/3000 [==============================] - 0s 59us/step - loss: 0.1948
# Epoch 13/30
# 3000/3000 [==============================] - 0s 57us/step - loss: 0.1945
# Epoch 14/30
# 3000/3000 [==============================] - 0s 60us/step - loss: 0.1949
# Epoch 15/30
# 3000/3000 [==============================] - 0s 61us/step - loss: 0.1949
# Epoch 16/30
# 3000/3000 [==============================] - 0s 59us/step - loss: 0.1943
# Epoch 17/30
# 3000/3000 [==============================] - 0s 55us/step - loss: 0.1945
# Epoch 18/30
# 3000/3000 [==============================] - 0s 61us/step - loss: 0.1949
# Epoch 19/30
# 3000/3000 [==============================] - 0s 63us/step - loss: 0.1949
# Epoch 20/30
# 3000/3000 [==============================] - 0s 60us/step - loss: 0.1947
# Epoch 21/30
# 3000/3000 [==============================] - 0s 57us/step - loss: 0.1949
# Epoch 22/30
# 3000/3000 [==============================] - 0s 55us/step - loss: 0.1948
# Epoch 23/30
# 3000/3000 [==============================] - 0s 55us/step - loss: 0.1948
# Epoch 24/30
# 3000/3000 [==============================] - 0s 62us/step - loss: 0.1947
# Epoch 25/30
# 3000/3000 [==============================] - 0s 56us/step - loss: 0.1946
# Epoch 26/30
# 3000/3000 [==============================] - 0s 61us/step - loss: 0.1950
# Epoch 27/30
# 3000/3000 [==============================] - 0s 59us/step - loss: 0.1947
# Epoch 28/30
# 3000/3000 [==============================] - 0s 63us/step - loss: 0.1948
# Epoch 29/30
# 3000/3000 [==============================] - 0s 59us/step - loss: 0.1949
# Epoch 30/30
# 3000/3000 [==============================] - 0s 58us/step - loss: 0.1948
# 	Train accuracy: 79.26666666666667 %
# 	Test accuracy: 77.60000000000001 %
# 	Weight:
# [array([[1.3132006],
#        [0.3257499],
#        [0.3575959]], dtype=float32), array([3.0292718], dtype=float32)]

# %% [markdown]
# We reach the accuracy of around **78%** on the test set.
# The effect of epochs on the accuracy is not clear in this example. When I first ran the code I thought more epochs would increase the accuracy. But after I rerun the code block I got different effects.

# %%
# Does batch_size have an effect
epochs = 25
batch_size_list = [5, 10, 25, 50, 100]

for batch_size in batch_size_list:
    predict(epochs, batch_size)
# Out:
# #############################################################################################
# Training model with epochs = 25, batch_size = 5
# Epoch 1/25
# 3000/3000 [==============================] - 1s 230us/step - loss: 0.1961
# Epoch 2/25
# 3000/3000 [==============================] - 1s 214us/step - loss: 0.1964
# Epoch 3/25
# 3000/3000 [==============================] - 1s 202us/step - loss: 0.1944
# Epoch 4/25
# 3000/3000 [==============================] - 1s 266us/step - loss: 0.1962
# Epoch 5/25
# 3000/3000 [==============================] - 1s 204us/step - loss: 0.1968
# Epoch 6/25
# 3000/3000 [==============================] - 1s 210us/step - loss: 0.1964
# Epoch 7/25
# 3000/3000 [==============================] - 1s 274us/step - loss: 0.1964
# Epoch 8/25
# 3000/3000 [==============================] - 1s 204us/step - loss: 0.1961
# Epoch 9/25
# 3000/3000 [==============================] - 1s 248us/step - loss: 0.1966
# Epoch 10/25
# 3000/3000 [==============================] - 1s 231us/step - loss: 0.1963
# Epoch 11/25
# 3000/3000 [==============================] - 1s 282us/step - loss: 0.1960
# Epoch 12/25
# 3000/3000 [==============================] - 1s 316us/step - loss: 0.1961
# Epoch 13/25
# 3000/3000 [==============================] - 1s 226us/step - loss: 0.1967
# Epoch 14/25
# 3000/3000 [==============================] - 1s 265us/step - loss: 0.1970
# Epoch 15/25
# 3000/3000 [==============================] - 1s 230us/step - loss: 0.1958
# Epoch 16/25
# 3000/3000 [==============================] - 1s 317us/step - loss: 0.1968
25
# 3000/3000 [==============================] - 0s 28us/step - loss: 0.1944
# Epoch 17/25
# 3000/3000 [==============================] - 0s 27us/step - loss: 0.1944
# Epoch 18/25
# 3000/3000 [==============================] - 0s 28us/step - loss: 0.1944
# Epoch 19/25
# 3000/3000 [==============================] - 0s 28us/step - loss: 0.1944
# Epoch 20/25
# 3000/3000 [==============================] - 0s 28us/step - loss: 0.1944
# Epoch 21/25
# 3000/3000 [==============================] - 0s 28us/step - loss: 0.1944
# Epoch 22/25
# 3000/3000 [==============================] - 0s 28us/step - loss: 0.1944
# Epoch 23/25
# 3000/3000 [==============================] - 0s 29us/step - loss: 0.1944
# Epoch 24/25
# 3000/3000 [==============================] - 0s 32us/step - loss: 0.1944
# Epoch 25/25
# 3000/3000 [==============================] - 0s 31us/step - loss: 0.1944
# 	Train accuracy: 79.86666666666666 %
# 	Test accuracy: 78.7 %
# 	Weight:
# [array([[1.3047019 ],
#        [0.32717434],
#        [0.35809228]], dtype=float32), array([3.035168], dtype=float32)]
# #############################################################################################
# Training model with epochs = 25, batch_size = 100
# Epoch 1/25
# 3000/3000 [==============================] - 0s 13us/step - loss: 0.1943
# Epoch 2/25
# 3000/3000 [==============================] - 0s 18us/step - loss: 0.1942
# Epoch 3/25
# 3000/3000 [==============================] - 0s 14us/step - loss: 0.1943
# Epoch 4/25
# 3000/3000 [==============================] - 0s 14us/step - loss: 0.1942
# Epoch 5/25
# 3000/3000 [==============================] - 0s 17us/step - loss: 0.1942
# Epoch 6/25
# 3000/3000 [==============================] - 0s 16us/step - loss: 0.1942
# Epoch 7/25
# 3000/3000 [==============================] - 0s 16us/step - loss: 0.1942
# Epoch 8/25
# 3000/3000 [==============================] - 0s 19us/step - loss: 0.1942
# Epoch 9/25
# 3000/3000 [==============================] - 0s 18us/step - loss: 0.1942
# Epoch 10/25
# 3000/3000 [==============================] - 0s 18us/step - loss: 0.1943
# Epoch 11/25
# 3000/3000 [==============================] - 0s 17us/step - loss: 0.1942
# Epoch 12/25
# 3000/3000 [==============================] - 0s 21us/step - loss: 0.1942
# Epoch 13/25
# 3000/3000 [==============================] - 0s 15us/step - loss: 0.1942
# Epoch 14/25
# 3000/3000 [==============================] - 0s 17us/step - loss: 0.1942
# Epoch 15/25
# 3000/3000 [==============================] - 0s 18us/step - loss: 0.1942
# Epoch 16/25
# 3000/3000 [==============================] - 0s 18us/step - loss: 0.1943
# Epoch 17/25
# 3000/3000 [==============================] - 0s 16us/step - loss: 0.1943
# Epoch 18/25
# 3000/3000 [==============================] - 0s 15us/step - loss: 0.1942
# Epoch 19/25
# 3000/3000 [==============================] - 0s 14us/step - loss: 0.1943
# Epoch 20/25
# 3000/3000 [==============================] - 0s 17us/step - loss: 0.1942
# Epoch 21/25
# 3000/3000 [==============================] - 0s 18us/step - loss: 0.1942
# Epoch 22/25
# 3000/3000 [==============================] - 0s 15us/step - loss: 0.1942
# Epoch 23/25
# 3000/3000 [==============================] - 0s 15us/step - loss: 0.1943
# Epoch 24/25
# 3000/3000 [==============================] - 0s 20us/step - loss: 0.1942
# Epoch 25/25
# 3000/3000 [==============================] - 0s 15us/step - loss: 0.1942
# 	Train accuracy: 79.86666666666666 %
# 	Test accuracy: 78.7 %
# 	Weight:
# [array([[1.3034441 ],
#        [0.32521862],
#        [0.3573995 ]], dtype=float32), array([3.034707], dtype=float32)]

# %% [markdown]
# The smaller the batch_size the longer it took to train the model. Other than that, the effect of batch_size on the accuracy is not clear because we got different effects everytime we reran the code.

# %% [markdown]
# *Do the weights you get make sense?*
#
# From the weights I get, I could see that the 1st feature has the most effect on the grade, maybe it's the exam grade.
